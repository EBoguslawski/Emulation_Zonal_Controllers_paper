# %%
import grid2op
from utils import *

env_name = "l2rpn_idf_2023_val"
agent_name = "agent_default_no_redisp_LinesCapacityReward_CustomGymEnv_0.85_0.9_sum_3x300_bis_lr2_10M_3"
load_path = "/home/boguslawskieva/PSCC_idf_2023/saved_model_2023/"
# Out:
# 2023-11-17 17:15:07.778400: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /data/boguslawskieva_data/L2RPN-WCCI-Baselines/venv_baselines_dev/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-11-17 17:15:07.778420: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
env_val = grid2op.make(env_name)        


my_agent = load_agent(env_val, load_path,
                            agent_name,
                            GymEnv,
                )

# %%
type(my_agent.nn_model)
# Out:
# stable_baselines3.ppo.ppo.PPO

# %%
my_agent.nn_model.policy.activation_fn
my_agent.nn_model.policy.action_net, my_agent.nn_model.policy.value_net
# Out:
# (Linear(in_features=300, out_features=49, bias=True),
#  Linear(in_features=300, out_features=1, bias=True))

# %%
my_agent.nn_model.get_parameters()['policy.optimizer']
# Out:
# {'state': {0: {'step': tensor(1562560., device='cuda:0'),
#    'exp_avg': tensor([ 7.2770e-07, -4.9059e-07,  3.1427e-06, -7.6037e-07,  2.7494e-07,
#            -9.3896e-07, -1.2178e-06, -3.2218e-07,  6.6766e-07,  1.7294e-06,
#             4.0658e-07,  8.5529e-07,  1.2528e-07, -2.3095e-06,  5.9974e-07,
#             4.1323e-07, -1.7542e-06,  1.2276e-06,  1.2763e-06,  8.1126e-07,
#            -5.6829e-07,  1.8440e-06,  2.1801e-07, -6.5184e-07, -1.1391e-06,
#             1.0030e-07, -4.1788e-07,  7.3298e-08, -6.6728e-07,  5.9440e-07,
#             1.6298e-06, -2.9379e-07,  8.5261e-09, -8.2475e-07, -3.8836e-07,
#            -2.0109e-07, -4.6700e-07,  4.9615e-07,  2.1240e-06, -4.6307e-07,
#             3.7627e-07, -2.0793e-07,  4.5014e-07, -2.2818e-06, -7.4325e-07,
#             1.5661e-07, -4.9985e-07, -1.6652e-06,  9.8385e-07], device='cuda:0'),
#    'exp_avg_sq': tensor([1.8743e-11, 1.9060e-11, 2.3640e-11, 1.7755e-11, 1.8884e-11, 1.8119e-11,
# ...
